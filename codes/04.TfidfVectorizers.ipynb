# %% [markdown]
# ## TF-IDF(단어 빈도 - 역 문서 빈도)
#
# - 전체 문장 대비 선택한 문장에 희귀하게 등장하는 단어가 중요도 강함

# %%
it_sentences = [
    "인공지능 기술이 사회의 다양한 분야에 점점 더 널리 적용되고 있다.",
    "클라우드 컴퓨팅은 데이터 저장과 처리를 더욱 효율적으로 만들어 주며, 기업의 IT 인프라를 혁신하고 있다.",
    "머신러닝과 딥러닝 알고리즘은 데이터 분석과 예측 모델링에 혁명을 일으키고 있다.",
    "블록체인 기술은 금융 거래의 투명성과 보안성을 향상시키는데 기여하고 있다.",
    "사이버 보안은 디지털 시대의 중요한 이슈로 부상하고 있으며, 지속적인 관심과 개선이 요구된다.",
    "소프트웨어 개발에서의 애자일 방법론은 빠른 시장 변화에 효과적으로 대응할 수 있게 해준다.",
    "데이터 과학과 분석은 비즈니스 의사 결정 과정에서 중요한 역할을 하며, 기업의 경쟁력을 강화시킨다.",
    "사물인터넷(IoT) 기술은 일상 생활을 더욱 편리하고 연결된 공간으로 변화시키고 있다.",
    "가상현실(VR)과 증강현실(AR) 기술은 엔터테인먼트, 교육, 의료 등 다양한 분야에서 새로운 경험을 제공한다.",
    "파이썬은 데이터 과학, 웹 개발, 자동화 스크립트 작성 등 다양한 프로그래밍 작업에 널리 사용되는 언어이다."
]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer # Word Embedding
# tfidfVectorizer = TfidfVectorizer()
tfidfVectorizer = TfidfVectorizer(stop_words=['인공지능', 'it'], ngram_range=(1,3))
tfidfVectorizer.fit(it_sentences) # 학습용
# Out:
# TfidfVectorizer(ngram_range=(1, 3), stop_words=['인공지능', 'it'])

# %%
tfidfVectorizer.vocabulary_ # 언어 사전 완성
# Out:
# {'기술이': 59,
#  '사회의': 159,
#  '다양한': 74,
#  '분야에': 136,
#  '점점': 237,
#  '널리': 69,
#  '적용되고': 235,
#  '있다': 219,
#  '기술이 사회의': 60,
#  '사회의 다양한': 160,
#  '다양한 분야에': 75,
#  '분야에 점점': 137,
#  '점점 널리': 238,
#  '널리 적용되고': 72,
#  '적용되고 있다': 236,
#  '기술이 사회의 다양한': 61,
#  '사회의 다양한 분야에': 161,
#  '다양한 분야에 점점': 76,
#  '분야에 점점 널리': 138,
#  '점점 널리 적용되고': 239,
#  '널리 적용되고 있다': 73,
#  '클라우드': 261,
#  '컴퓨팅은': 258,
#  '데이터': 89,
#  '저장과': 232,
#  '처리를': 255,
#  '더욱': 84,
#  '효율적으로': 291,
#  '만들어': 104,
#  '주며': 241,
#  '기업의': 62,
#  '인프라를': 209,
#  '혁신하고': 286,
#  '클라우드 컴퓨팅은': 262,
#  '컴퓨팅은 데이터': 259,
#  '데이터 저장과': 96,
#  '저장과 처리를': 233,
#  '처리를 더욱': 256,
#  '더욱 효율적으로': 87,
#  '효율적으로 만들어': 292,
#  '만들어 주며': 105,
#  '주며 기업의': 242,
#  '기업의 인프라를': 65,
#  '인프라를 혁신하고': 210,
#  '혁신하고 있다': 287,
#  '클라우드 컴퓨팅은 데이터': 263,
#  '컴퓨팅은 데이터 저장과': 260,
#  '데이터 저장과 처리를': 97,
#  '저장과 처리를 더욱': 234,
#  '처리를 더욱 효율적으로': 257,
#  '더욱 효율적으로 만들어': 88,
#  '효율적으로 만들어 주며': 293,
#  '만들어 주며 기업의': 106,
#  '주며 기업의 인프라를': 243,
#  '기업의 인프라를 혁신하고': 66,
#  '인프라를 혁신하고 있다': 211,
#  '머신러닝과': 107,
#  '딥러닝': 101,
#  '알고리즘은': 180,
#  '분석과': 130,
#  '예측': 196,
#  '모델링에': 110,
#  '혁명을': 283,
#  '일으키고': 215,
#  '머신러닝과 딥러닝': 108,
#  '딥러닝 알고리즘은': 102,
#  '알고리즘은 데이터': 181,
#  '데이터 분석과': 94,
#  '분석과 예측': 131,
#  '예측 모델링에': 197,
#  '모델링에 혁명을': 111,
#  '혁명을 일으키고': 284,
#  '일으키고 있다': 216,
#  '머신러닝과 딥러닝 알고리즘은': 109,
#  '딥러닝 알고리즘은 데이터': 103,
#  '알고리즘은 데이터 분석과': 182,
#  '데이터 분석과 예측': 95,
#  '분석과 예측 모델링에': 132,
#  '예측 모델링에 혁명을': 198,
#  '모델링에 혁명을 일으키고': 112,
#  '혁명을 일으키고 있다': 285,
#  '블록체인': 142,
#  '기술은': 52,
#  '금융': 49,
#  '거래의': 21,
#  '투명성과': 264,
#  '보안성을': 121,
#  '향상시키는데': 280,
#  '기여하고': 67,
#  '블록체인 기술은': 143,
#  '기술은 금융': 53,
#  '금융 거래의': 50,
#  '거래의 투명성과': 22,
#  '투명성과 보안성을': 265,
#  '보안성을 향상시키는데': 122,
#  '향상시키는데 기여하고': 281,
#  '기여하고 있다': 68,
#  '블록체인 기술은 금융': 144,
#  '기술은 금융 거래의': 54,
#  '금융 거래의 투명성과': 51,
#  '거래의 투명성과 보안성을': 23,
#  '투명성과 보안성을 향상시키는데': 266,
#  '보안성을 향상시키는데 기여하고': 123,
#  '향상시키는데 기여하고 있다': 282,
#  '사이버': 156,
#  '보안은': 124,
#  '디지털': 98,
#  '시대의': 174,
#  '중요한': 244,
#  '이슈로': 206,
#  '부상하고': 127,
#  '있으며': 220,
#  '지속적인': 252,
#  '관심과': 43,
#  '개선이': 19,
#  '요구된다': 199,
#  '사이버 보안은': 157,
#  '보안은 디지털': 125,
#  '디지털 시대의': 99,
#  '시대의 중요한': 175,
#  '중요한 이슈로': 247,
#  '이슈로 부상하고': 207,
#  '부상하고 있으며': 128,
#  '있으며 지속적인': 221,
#  '지속적인 관심과': 253,
#  '관심과 개선이': 44,
#  '개선이 요구된다': 20,
#  '사이버 보안은 디지털': 158,
#  '보안은 디지털 시대의': 126,
#  '디지털 시대의 중요한': 100,
#  '시대의 중요한 이슈로': 176,
#  '중요한 이슈로 부상하고': 248,
#  '이슈로 부상하고 있으며': 208,
#  '부상하고 있으며 지속적인': 129,
#  '있으며 지속적인 관심과': 222,
#  '지속적인 관심과 개선이': 254,
#  '관심과 개선이 요구된다': 45,
#  '소프트웨어': 168,
#  '개발에서의': 16,
#  '애자일': 183,
#  '방법론은': 113,
#  '빠른': 148,
#  '시장': 177,
#  '변화에': 118,
#  '효과적으로': 288,
#  '대응할': 81,
#  '있게': 217,
#  '해준다': 279,
#  '소프트웨어 개발에서의': 169,
#  '개발에서의 애자일': 17,
#  '애자일 방법론은': 184,
#  '방법론은 빠른': 114,
#  '빠른 시장': 149,
#  '시장 변화에': 178,
#  '변화에 효과적으로': 119,
#  '효과적으로 대응할': 289,
#  '대응할 있게': 82,
#  '있게 해준다': 218,
#  '소프트웨어 개발에서의 애자일': 170,
#  '개발에서의 애자일 방법론은': 18,
#  '애자일 방법론은 빠른': 185,
#  '방법론은 빠른 시장': 115,
#  '빠른 시장 변화에': 150,
#  '시장 변화에 효과적으로': 179,
#  '변화에 효과적으로 대응할': 120,
#  '효과적으로 대응할 있게': 290,
#  '대응할 있게 해준다': 83,
#  '과학과': 40,
#  '분석은': 133,
#  '비즈니스': 145,
#  '의사': 203,
#  '결정': 24,
#  '과정에서': 34,
#  '역할을': 190,
#  '하며': 276,
#  '경쟁력을': 27,
#  '강화시킨다': 12,
#  '데이터 과학과': 92,
#  '과학과 분석은': 41,
#  '분석은 비즈니스': 134,
#  '비즈니스 의사': 146,
#  '의사 결정': 204,
#  '결정 과정에서': 25,
#  '과정에서 중요한': 35,
#  '중요한 역할을': 245,
#  '역할을 하며': 191,
#  '하며 기업의': 277,
#  '기업의 경쟁력을': 63,
#  '경쟁력을 강화시킨다': 28,
#  '데이터 과학과 분석은': 93,
#  '과학과 분석은 비즈니스': 42,
#  '분석은 비즈니스 의사': 135,
#  '비즈니스 의사 결정': 147,
#  '의사 결정 과정에서': 205,
#  '결정 과정에서 중요한': 26,
#  '과정에서 중요한 역할을': 36,
#  '중요한 역할을 하며': 246,
#  '역할을 하며 기업의': 192,
#  '하며 기업의 경쟁력을': 278,
#  '기업의 경쟁력을 강화시킨다': 64,
#  '사물인터넷': 151,
#  'iot': 3,
#  '일상': 212,
#  '생활을': 165,
#  '편리하고': 270,
#  '연결된': 193,
#  '공간으로': 31,
#  '변화시키고': 116,
#  '사물인터넷 iot': 152,
#  'iot 기술은': 4,
#  '기술은 일상': 57,
#  '일상 생활을': 213,
#  '생활을 더욱': 166,
#  '더욱 편리하고': 85,
#  '편리하고 연결된': 271,
#  '연결된 공간으로': 194,
#  '공간으로 변화시키고': 32,
#  '변화시키고 있다': 117,
#  '사물인터넷 iot 기술은': 153,
#  'iot 기술은 일상': 5,
#  '기술은 일상 생활을': 58,
#  '일상 생활을 더욱': 214,
#  '생활을 더욱 편리하고': 167,
#  '더욱 편리하고 연결된': 86,
#  '편리하고 연결된 공간으로': 272,
#  '연결된 공간으로 변화시키고': 195,
#  '공간으로 변화시키고 있다': 33,
#  '가상현실': 9,
#  'vr': 6,
#  '증강현실': 249,
#  'ar': 0,
#  '엔터테인먼트': 187,
#  '교육': 46,
#  '의료': 200,
#  '분야에서': 139,
#  '새로운': 162,
#  '경험을': 29,
#  '제공한다': 240,
#  '가상현실 vr': 10,
#  'vr 증강현실': 7,
#  '증강현실 ar': 250,
#  'ar 기술은': 1,
#  '기술은 엔터테인먼트': 55,
#  '엔터테인먼트 교육': 188,
#  '교육 의료': 47,
#  '의료 다양한': 201,
#  '다양한 분야에서': 77,
#  '분야에서 새로운': 140,
#  '새로운 경험을': 163,
#  '경험을 제공한다': 30,
#  '가상현실 vr 증강현실': 11,
#  'vr 증강현실 ar': 8,
#  '증강현실 ar 기술은': 251,
#  'ar 기술은 엔터테인먼트': 2,
#  '기술은 엔터테인먼트 교육': 56,
#  '엔터테인먼트 교육 의료': 189,
#  '교육 의료 다양한': 48,
#  '의료 다양한 분야에서': 202,
#  '다양한 분야에서 새로운': 78,
#  '분야에서 새로운 경험을': 141,
#  '새로운 경험을 제공한다': 164,
#  '파이썬은': 267,
#  '과학': 37,
#  '개발': 13,
#  '자동화': 223,
#  '스크립트': 171,
#  '작성': 226,
#  '프로그래밍': 273,
#  '작업에': 229,
#  '사용되는': 154,
#  '언어이다': 186,
#  '파이썬은 데이터': 268,
#  '데이터 과학': 90,
#  '과학 개발': 38,
#  '개발 자동화': 14,
#  '자동화 스크립트': 224,
#  '스크립트 작성': 172,
#  '작성 다양한': 227,
#  '다양한 프로그래밍': 79,
#  '프로그래밍 작업에': 274,
#  '작업에 널리': 230,
#  '널리 사용되는': 70,
#  '사용되는 언어이다': 155,
#  '파이썬은 데이터 과학': 269,
#  '데이터 과학 개발': 91,
#  '과학 개발 자동화': 39,
#  '개발 자동화 스크립트': 15,
#  '자동화 스크립트 작성': 225,
#  '스크립트 작성 다양한': 173,
#  '작성 다양한 프로그래밍': 228,
#  '다양한 프로그래밍 작업에': 80,
#  '프로그래밍 작업에 널리': 275,
#  '작업에 널리 사용되는': 231,
#  '널리 사용되는 언어이다': 71}

# %%
tfidfVectorizer.get_feature_names_out(), tfidfVectorizer.idf_
tfidfVectorizer.get_feature_names_out().shape, tfidfVectorizer.idf_.shape
# Out:
# ((294,), (294,))

# %%
result_vectors = tfidfVectorizer.transform(it_sentences) # 서비스용
# result_vectors
# result_vectors.toarray()
result_vectors.toarray().shape
# Out:
# (10, 294)

# %%
import pandas as pd
pd.DataFrame(data=result_vectors.toarray(), columns=tfidfVectorizer.get_feature_names_out()).T
# Out:
#                  0         1    2    3  ...    6         7         8    9
# ar             0.0  0.000000  0.0  0.0  ...  0.0  0.000000  0.168775  0.0
# ar 기술은         0.0  0.000000  0.0  0.0  ...  0.0  0.000000  0.168775  0.0
# ar 기술은 엔터테인먼트  0.0  0.000000  0.0  0.0  ...  0.0  0.000000  0.168775  0.0
# iot            0.0  0.000000  0.0  0.0  ...  0.0  0.186897  0.000000  0.0
# iot 기술은        0.0  0.000000  0.0  0.0  ...  0.0  0.186897  0.000000  0.0
# ...            ...       ...  ...  ...  ...  ...       ...       ...  ...
# 효과적으로 대응할      0.0  0.000000  0.0  0.0  ...  0.0  0.000000  0.000000  0.0
# 효과적으로 대응할 있게   0.0  0.000000  0.0  0.0  ...  0.0  0.000000  0.000000  0.0
# 효율적으로          0.0  0.170909  0.0  0.0  ...  0.0  0.000000  0.000000  0.0
# 효율적으로 만들어      0.0  0.170909  0.0  0.0  ...  0.0  0.000000  0.000000  0.0
# 효율적으로 만들어 주며   0.0  0.170909  0.0  0.0  ...  0.0  0.000000  0.000000  0.0
#
# [294 rows x 10 columns]
